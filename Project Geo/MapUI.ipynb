# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
plotly.tools.set_credentials_file(username='AshuPareekL', api_key = 'mGZrhGaLZhNfwWgMSZnV')

# %%
import pandas as pd
import numpy as np
import random

# %%
import re
df_final = pd.read_csv('finaldf.csv')
df_state = pd.read_csv('clean_msa2.csv')
    
    
    #print(val)
    #print(df_state.loc[df_state['County'] == df_final['County'].iloc[index] & (df_state['MSA'] == df_final['MSA'].iloc[index])])
    #a.append(df_sample1[df_sample1['County'] == val + " "]['County'])

# %%
import re 
new_df = pd.merge(df_state, df_final,  how='left', left_on=['MSA','County'], right_on = ['MSA','County'])
new_df = new_df.dropna()
new_df['Full County Name'] = new_df["County"].map(str) + ", " + new_df["State_y"]
df_sample = pd.read_csv('laucnty16.csv')
df_sample['State FIPS Code'] = df_sample['State FIPS Code'].apply(lambda x: str(x).zfill(2))
df_sample['County FIPS Code'] = df_sample['County FIPS Code'].apply(lambda x: str(x).zfill(3))
df_sample['FIPS'] = df_sample['State FIPS Code'] + df_sample['County FIPS Code']
df_sample['County Name/State Abbreviation'] = df_sample['County Name/State Abbreviation'].apply(lambda x: re.sub(" County", "", x))

new_df = pd.merge(df_sample, new_df, how='left', left_on=['County Name/State Abbreviation'], right_on = ['Full County Name'])
new_df.fillna(3)
# Out:
#             LAUS Code State FIPS Code County FIPS Code  \
# 0     CN0100100000000              01              001
# 1     CN0100300000000              01              003
# 2     CN0100500000000              01              005
# 3     CN0100700000000              01              007
# 4     CN0100900000000              01              009
# 5     CN0101100000000              01              011
# 6     CN0101300000000              01              013
# 7     CN0101500000000              01              015
# 8     CN0101700000000              01              017
# 9     CN0101900000000              01              019
# 10    CN0102100000000              01              021
# 11    CN0102300000000              01              023
# 12    CN0102500000000              01              025
# 13    CN0102700000000              01              027
# 14    CN0102900000000              01              029
# 15    CN0103100000000              01              031
# ...

# %%
df_sample = pd.read_csv('laucnty16.csv')
df_sample['State FIPS Code'] = df_sample['State FIPS Code'].apply(lambda x: str(x).zfill(2))
df_sample['County FIPS Code'] = df_sample['County FIPS Code'].apply(lambda x: str(x).zfill(3))
df_sample['FIPS'] = df_sample['State FIPS Code'] + df_sample['County FIPS Code']

colorscale = ["#6b6b6b","#0b5de2","#000000", '#dfe20b']

endpts = list(np.linspace(0, 2, 3))
fips = new_df['FIPS'].tolist()
values = new_df['Predictions'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=False,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='Innovation Hub Classification',
    legend_title='Classification'
)

py.iplot(fig, filename='choropleth_full_usa')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~AshuPareekL/2.embed" height="450px" width="900px"></iframe>
